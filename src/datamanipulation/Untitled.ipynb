# %%
import pandas as pd

flights_file = pd.read_csv('/Users/toszafar/code/python-projects/python-code-samples/python-logging-framework/src/datamanipulation/flights.csv')
flights_file.drop(["DAY_OF_WEEK"],axis=1)
flights_file.rename(index=str, columns={"WHEELS_OFF": "HAS_WHEELS"})

#length of the dataset
#print(len(flights_file))

#select data using column headings
#print(flights_file['DESTINATION_AIRPORT'])
# OR
#print(flights_file.DESTINATION_AIRPORT)

#putting a column into an object
# new_object = flights_file['DESTINATION_AIRPORT']
# print(new_object[0:10])

chunk_size = len(flights_file) // 4

chunk1 = flights_file[0:chunk_size]
chunk2 = flights_file[chunk_size:chunk_size*2]
chunk3 = flights_file[chunk_size*2:chunk_size*3]
chunk4 = flights_file[chunk_size*3:chunk_size*4]

combined_chunks_list = [chunk1, chunk2, chunk3, chunk4]
combined_chunks = pd.concat(combined_chunks_list)
chunk_aa = combined_chunks[combined_chunks.AIRLINE == 'AA']
chunk_aa_delay = chunk_aa[(chunk_aa.DEPARTURE_DELAY < 10) & (chunk_aa.DESTINATION_AIRPORT == 'PBI')]

#average_airline_system_delay = chunk_aa_delay["AIR_SYSTEM_DELAY"].mean()
#average_airline_system_delay 
chunk_aa_delay['AIR_SYSTEM_DELAY']=chunk_aa_delay['AIR_SYSTEM_DELAY'].fillna(chunk_aa_delay['AIR_SYSTEM_DELAY'].mean())
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
import pandas as pd

flights_file = pd.read_csv('/Users/toszafar/code/python-projects/python-code-samples/python-logging-framework/src/datamanipulation/flights.csv')
standard_deviation = flights_file['DEPARTURE_DELAY'].std()
standard_deviation
mean_value = flights_file['DEPARTURE_DELAY'].mean()
mean_value
flights_file[flights_file['DEPARTURE_DELAY'] > (mean_value + 3 * standard_deviation)]
flights_file['has_A'] = flights_file['AIRLINE'].apply(lambda x: 1 if 'A' in x else 0 )
flights_file
# Out:
#         YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0       2015      1    1            4      AS             98      N407AS
# 1       2015      1    1            4      AA           2336      N3KUAA
# 2       2015      1    1            4      US            840      N171US
# 3       2015      1    1            4      AA            258      N3HYAA
# 4       2015      1    1            4      AS            135      N527AS
# 5       2015      1    1            4      DL            806      N3730B
# 6       2015      1    1            4      NK            612      N635NK
# 7       2015      1    1            4      US           2013      N584UW
# 8       2015      1    1            4      AA           1112      N3LAAA
# 9       2015      1    1            4      DL           1173      N826DN
# 10      2015      1    1            4      DL           2336      N958DN
# 11      2015      1    1            4      AA           1674      N853AA
# ...

# %%
flights_file = pd.read_csv('/Users/toszafar/code/python-projects/python-code-samples/python-logging-framework/src/datamanipulation/flights.csv')
flights_file.groupby('AIRLINE')['DEPARTURE_DELAY'].mean()
# Out:
# AIRLINE
# AA    10.643729
# AS     3.430815
# B6    10.774558
# DL     6.775430
# EV    10.043026
# F9    19.664576
# HA     1.109583
# MQ    16.141276
# NK    14.016792
# OO    12.458124
# UA    14.169355
# US     6.108520
# VX     6.815032
# WN     9.631559
# Name: DEPARTURE_DELAY, dtype: float64

# %%
x = pd.read_csv('/Users/toszafar/code/python-projects/python-code-samples/python-logging-framework/src/datamanipulation/flights.csv')
x = flights_file.groupby('AIRLINE')
x.apply(lambda x: x[x['DEPARTURE_TIME'] < 1200]['DEPARTURE_TIME'].count())
# Out:
# AIRLINE
# AA    18405
# AS     6127
# B6     8952
# DL    28126
# EV    19802
# F9     2714
# HA     2790
# MQ    11434
# NK     3856
# OO    19539
# UA    16805
# US    15087
# VX     2016
# WN    41471
# dtype: int64

# %%
print('asdf')
# Out:
# asdf
